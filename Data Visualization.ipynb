# %% [markdown]
# **Data Visualization**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Cleaned_Data.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8359 entries, 0 to 8358
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Fuel Type           8359 non-null   object
#  1   Body Type           8359 non-null   object
#  2   Transmission        8359 non-null   object
#  3   Owner No            8359 non-null   int64
#  4   Brand               8359 non-null   object
#  5   Model               8359 non-null   object
#  6   Model Year          8359 non-null   int64
#  7   Price               8359 non-null   float64
#  8   Insurance Validity  8359 non-null   object
#  9   Kms Driven          8359 non-null   int64
#  10  Mileage             8359 non-null   float64
#  11  Seats               8359 non-null   int64
#  12  Color               8359 non-null   object
#  13  City                8359 non-null   object
# dtypes: float64(2), int64(4), object(8)
# memory usage: 914.4+ KB

# %%
df
# Out:
#      Fuel Type  Body Type Transmission  Owner No          Brand  \
# 0       Petrol  Hatchback       Manual         3         Maruti
# 1       Petrol        SUV       Manual         2           Ford
# 2       Petrol  Hatchback       Manual         1           Tata
# 3       Petrol      Sedan       Manual         1        Hyundai
# 4       Diesel        SUV       Manual         1         Maruti
# ...        ...        ...          ...       ...            ...
# 8354    Petrol  Hatchback       Manual         1         Maruti
# 8355    Petrol  Hatchback       Manual         1         Maruti
# 8356    Petrol      Sedan    Automatic         3  Mercedes-Benz
# 8357    Petrol  Hatchback       Manual         1         Maruti
# 8358    Diesel        SUV       Manual         2        Renault
#
#                       Model  Model Year  Price     Insurance Validity  \
# 0            Maruti Celerio        2015   4.00  Third Party insurance
# 1             Ford Ecosport        2018   8.11          Comprehensive
# 2                Tata Tiago        2018   5.85          Comprehensive
# 3             Hyundai Xcent        2014   4.62          Comprehensive
# 4        Maruti SX4 S Cross        2015   7.90  Third Party insurance
# ...                     ...         ...    ...                    ...
# 8354         Maruti Celerio        2022   5.10  Third Party insurance
# 8355        Maruti Alto 800        2014   1.80  Third Party insurance
# 8356  Mercedes-Benz C-Class        2011   5.50  Third Party insurance
# 8357            Maruti Ritz        2012   1.40  Third Party insurance
# 8358         Renault Duster        2017   5.00  Third Party insurance
#
#       Kms Driven  Mileage  Seats   Color       City
# 0         120000    23.10      5   White  Bangalore
# 1          32706    17.00      5   White  Bangalore
# 2          11949    23.84      5     Red  Bangalore
# 3          17794    19.10      5  Others  Bangalore
# 4          60000    23.65      5    Gray  Bangalore
# ...          ...      ...    ...     ...        ...
# 8354       10000    25.24      5  Others    Kolkata
# 8355      120000    22.74      5  Others    Kolkata
# 8356       50000    11.74      5  Others    Kolkata
# 8357       40000    18.50      5  Others    Kolkata
# 8358      120000    19.72      5  Others    Kolkata
#
# [8359 rows x 14 columns]

# %%
df["Fuel Type"].unique()
# Out:
# array(['Petrol', 'Diesel', 'Lpg', 'Cng', 'Electric'], dtype=object)

# %%
df["Fuel Type"].value_counts()
# Out:
# Fuel Type
# Petrol      5547
# Diesel      2671
# Cng           98
# Electric      27
# Lpg           16
# Name: count, dtype: int64

# %%
# visual the count of fuel type
plt.title("Count of Fuel Type")
sns.countplot(x=df["Fuel Type"],data=df,hue="Fuel Type")
plt.show()

# %%
df["Body Type"].unique()
# Out:
# array(['Hatchback', 'SUV', 'Sedan', 'MUV', 'Coupe', 'Minivans',
#        'Pickup Trucks', 'Convertibles', 'Hybrids', 'Wagon'], dtype=object)

# %%
df["Body Type"].value_counts()
# Out:
# Body Type
# Hatchback        3563
# SUV              2222
# Sedan            2171
# MUV               352
# Minivans           27
# Coupe              10
# Pickup Trucks       6
# Convertibles        6
# Hybrids             1
# Wagon               1
# Name: count, dtype: int64

# %%
# visual the count of body type
plt.figure(figsize=(12,6))
plt.title("Count of Body Type")
sns.countplot(x=df["Body Type"],data=df,hue="Body Type")
plt.show()

# %%
df["Transmission"].unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
df["Transmission"].value_counts()
# Out:
# Transmission
# Manual       6046
# Automatic    2313
# Name: count, dtype: int64

# %%
# visual the count of transmission
plt.figure(figsize=(5,5))
plt.title("Count of Transmission ")
plt.pie(df["Transmission"].value_counts(),autopct="%1.0f%%",labels=['Manual','Automatic'])
plt.show()

# %%
df["Brand"].unique()
# Out:
# array(['Maruti', 'Ford', 'Tata', 'Hyundai', 'Jeep', 'Datsun', 'Honda',
#        'Mahindra', 'Mercedes-Benz', 'BMW', 'Renault', 'Audi', 'Toyota',
#        'Mini', 'Kia', 'Skoda', 'Volkswagen', 'Volvo', 'MG', 'Nissan',
#        'Fiat', 'Mahindra Ssangyong', 'Mitsubishi', 'Jaguar', 'Land Rover',
#        'Chevrolet', 'Citroen', 'Opel', 'Mahindra Renault', 'Isuzu',
#        'Lexus', 'Porsche', 'Hindustan Motors'], dtype=object)

# %%
df["Brand"].value_counts()
# Out:
# Brand
# Maruti                2248
# Hyundai               1651
# Honda                  864
# Tata                   430
# Mahindra               376
# Toyota                 325
# Renault                311
# Ford                   311
# Volkswagen             294
# Mercedes-Benz          244
# BMW                    184
# Skoda                  160
# Kia                    158
# Audi                   156
# Jeep                   112
# MG                      90
# Nissan                  78
# Chevrolet               76
# Datsun                  74
# Land Rover              44
# Volvo                   41
# Jaguar                  35
# Fiat                    31
# Mitsubishi              14
# Mini                    12
# Citroen                  8
# Porsche                  6
# Lexus                    5
# Mahindra Renault         5
# Isuzu                    5
# Mahindra Ssangyong       4
# Hindustan Motors         4
# Opel                     3
# Name: count, dtype: int64

# %%
df["Model Year"].unique()
# Out:
# array([2015, 2018, 2014, 2020, 2017, 2021, 2019, 2022, 2016, 2011, 2009,
#        2013, 2010, 2008, 2006, 2012, 2005, 2007, 2023, 1998, 2004, 2003,
#        2001, 2002, 2000, 1985, 1997, 1999], dtype=int64)

# %%
df["Insurance Validity"].unique()
# Out:
# array(['Third Party insurance', 'Comprehensive', 'Third Party',
#        'Zero Dep', '2', '1', 'Not Available'], dtype=object)

# %%
df["Insurance Validity"].value_counts()
# Out:
# Insurance Validity
# Third Party insurance    4051
# Comprehensive            3150
# Third Party               630
# Zero Dep                  303
# Not Available             221
# 1                           3
# 2                           1
# Name: count, dtype: int64

# %%
df["Color"].unique()
# Out:
# array(['White', 'Red', 'Others', 'Gray', 'Grey', 'Maroon', 'Orange',
#        'Silver', 'Blue', 'Brown', 'Yellow', 'Black', 'Golden', 'Green',
#        'O Purple', 'Other', 'Gold', 'TITANIUM GREY', 'Violet',
#        'MODERN STEEL METALLIC', 'PLATINUM WHITE', 'Golden Brown',
#        'Aurora Black Pearl', 'Beige', 'Star Dust', 'Flash Red', 'Purple',
#        'PLATINUM WHITE PEARL', 'Wine Red', 'Taffeta White',
#        'Minimal Grey', 'Fiery Red', 'T Wine', 'Prime Star Gaze',
#        'TAFETA WHITE', 'P Black', 'Golden brown', 'METALL',
#        'MET ECRU BEIGE', 'COPPER', 'TITANIUM', 'CHILL', 'Burgundy',
#        'Lunar Silver Metallic', 'SILKY SILVER', 'BERRY RED',
#        'PREMIUM AMBER METALLIC', 'R EARTH', 'PLATINUM SILVER',
#        'ORCHID WHITE PEARL', 'CARNELIAN RED PEARL', 'POLAR WHITE',
#        'BEIGE', 'Medium Blue', 'Alabaster Silver Metallic',
#        'Carbon Steel', 'Cavern Grey', 'ESPRESO_BRWN', 'Pearl White',
#        'Polar White', 'Magma Grey', 'Dark Red', 'Falsa Colour', 'Cherry',
#        'Hip Hop Black', 'Nexa Blue', 'Passion Red', 'Cirrus White',
#        'Arizona Blue', 'Galaxy Blue', 'Silky Silver',
#        'Modern Steel Metal', 'GOLDEN BROWN', 'Burgundy Red Metallic',
#        'magma gray', 'CBeige', 'Goldan BRWOON', 'm grey', 'b red',
#        'Granite Grey', 'urban titanim', 'g brown', 'beige',
#        'Rosso Brunello', 'a silver', 'b grey', 'Radiant Red M',
#        'c bronze', 'Champagne Mica Metallic', 'Bold Beige Metallic',
#        'Starry Black', 'Sleek Silver', 'Symphony Silver', 'Phantom Black',
#        'Metallic Magma Grey', 'c brown', 'chill',
#        'Metallic Glistening Grey', 'Superior white',
#        'Modern Steel Metallic', 'Silky silver', 'Urban Titanium Metallic',
#        'Smoke Grey', 'Pearl Arctic White', 'Bright Silver',
#        'Porcelain White', 'Tafeta White', 'Coral White', 'Diamond White',
#        'Brick Red', 'Carnelian Red Pearl', 'Mediterranean Blue',
#        'Mist Silver', 'Gravity Gray', 'Candy White',
#        'Metallic Premium silver', 'Glistening Grey', 'Super white',
#        'Deep Black Pearl', 'Twilight Blue', 'Caviar Black',
#        'Pearl Met. Arctic White', 'Metallic silky silver', 'Pure white',
#        'StarDust', 'Alabaster Silver Metallic - Amaze', 'Ray blue',
#        'Glacier White Pearl', 'OUTBACK BRONZE', 'Solid Fire Red',
#        'Daytona Grey', 'Metallic Azure Grey', 'Moonlight Silver',
#        'Fire Brick Red', 'Cashmere', 'Pearl Snow White', 'Light Orange',
#        'Foliage', 'Sky Blue', 'Off White', 'Bronze', 'G Brown', 'Parpel',
#        'Outback Bronze', 'Cherry Red', 'Sunset Red', 'Silicon Silver',
#        'golden brown', 'Dark Blue', 'Technometgrn+Gryroof',
#        'Light Silver', 'Out Back Bronze'], dtype=object)

# %%
df["Body Type"].unique()
# Out:
# array(['Hatchback', 'SUV', 'Sedan', 'MUV', 'Coupe', 'Minivans',
#        'Pickup Trucks', 'Convertibles', 'Hybrids', 'Wagon'], dtype=object)

# %%
# histogram to visual the data distribution
df.hist(figsize=(10,8))
plt.show()

# %%
# scatterplot to visual the data distribution
plt.figure(figsize=(10, 6))
plt.title("Price vs Kms Driven")
sns.scatterplot(y='Price', x='Kms Driven', data=df)
plt.xlabel("Kms Driven")
plt.ylabel("Price")
plt.show()

# %%
df
# Out:
#      Fuel Type  Body Type Transmission  Owner No          Brand  \
# 0       Petrol  Hatchback       Manual         3         Maruti
# 1       Petrol        SUV       Manual         2           Ford
# 2       Petrol  Hatchback       Manual         1           Tata
# 3       Petrol      Sedan       Manual         1        Hyundai
# 4       Diesel        SUV       Manual         1         Maruti
# ...        ...        ...          ...       ...            ...
# 8354    Petrol  Hatchback       Manual         1         Maruti
# 8355    Petrol  Hatchback       Manual         1         Maruti
# 8356    Petrol      Sedan    Automatic         3  Mercedes-Benz
# 8357    Petrol  Hatchback       Manual         1         Maruti
# 8358    Diesel        SUV       Manual         2        Renault
#
#                       Model  Model Year  Price     Insurance Validity  \
# 0            Maruti Celerio        2015   4.00  Third Party insurance
# 1             Ford Ecosport        2018   8.11          Comprehensive
# 2                Tata Tiago        2018   5.85          Comprehensive
# 3             Hyundai Xcent        2014   4.62          Comprehensive
# 4        Maruti SX4 S Cross        2015   7.90  Third Party insurance
# ...                     ...         ...    ...                    ...
# 8354         Maruti Celerio        2022   5.10  Third Party insurance
# 8355        Maruti Alto 800        2014   1.80  Third Party insurance
# 8356  Mercedes-Benz C-Class        2011   5.50  Third Party insurance
# 8357            Maruti Ritz        2012   1.40  Third Party insurance
# 8358         Renault Duster        2017   5.00  Third Party insurance
#
#       Kms Driven  Mileage  Seats   Color       City
# 0         120000    23.10      5   White  Bangalore
# 1          32706    17.00      5   White  Bangalore
# 2          11949    23.84      5     Red  Bangalore
# 3          17794    19.10      5  Others  Bangalore
# 4          60000    23.65      5    Gray  Bangalore
# ...          ...      ...    ...     ...        ...
# 8354       10000    25.24      5  Others    Kolkata
# 8355      120000    22.74      5  Others    Kolkata
# 8356       50000    11.74      5  Others    Kolkata
# 8357       40000    18.50      5  Others    Kolkata
# 8358      120000    19.72      5  Others    Kolkata
#
# [8359 rows x 14 columns]

# %%
# scatterplot to visual the data distribution
plt.figure(figsize=(10, 6))
plt.title("Prive vs ModelYear")
sns.scatterplot(y='Price', x='Model Year', data=df)
plt.xlabel("Model Year")
plt.ylabel("Price")
plt.show()

# %%
# transmission and price
plt.figure(figsize=(10,6))
sns.boxplot(x='Transmission', y='Price', data=df)
plt.show()

# %%
# body type and price
plt.figure(figsize=(10,6))
sns.boxplot(x='Body Type', y='Price', data=df)
plt.show()

# %%
#distribution before outliers removing
sns.displot(x=df["Price"],kde=True)  # kde=True adds the KDE curve along with the histogram
plt.title("Distribution of Price")
plt.show()

# %%
df["Price"].count()
# Out:
# 8359

# %%
# Removing outliers from the 'price' column using IQR method
# Calculate Q1, Q3, and IQR
Q1 = df['Price'].quantile(0.25)
Q3 = df['Price'].quantile(0.75)
IQR = Q3 - Q1

# Filter out outliers from DataFrame
df_filtered = df[(df['Price'] >= (Q1 - 1.5 * IQR)) & (df['Price'] <= (Q3 + 1.5 * IQR))]

# Count of lower outliers
low_outliers = len(df[df['Price'] < (Q1 - 1.5 * IQR)])

# Count of upper outliers
high_outliers = len(df[df['Price'] > (Q3 + 1.5 * IQR)])

# Print outlier counts
print(f"Count of lower outliers: {low_outliers}")
print(f"Count of upper outliers: {high_outliers}")
# Out:
# Count of lower outliers: 0
# Count of upper outliers: 919

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='Body Type', y='Price', data=df_filtered)
plt.show()

# %%
#distribution after outliers removing
sns.displot(x=df_filtered["Price"], kde=True)  # kde=True adds the KDE curve along with the histogram
plt.title("Distribution of Price")
plt.show()

# %%
df_filtered
# Out:
#      Fuel Type  Body Type Transmission  Owner No          Brand  \
# 0       Petrol  Hatchback       Manual         3         Maruti
# 1       Petrol        SUV       Manual         2           Ford
# 2       Petrol  Hatchback       Manual         1           Tata
# 3       Petrol      Sedan       Manual         1        Hyundai
# 4       Diesel        SUV       Manual         1         Maruti
# ...        ...        ...          ...       ...            ...
# 8354    Petrol  Hatchback       Manual         1         Maruti
# 8355    Petrol  Hatchback       Manual         1         Maruti
# 8356    Petrol      Sedan    Automatic         3  Mercedes-Benz
# 8357    Petrol  Hatchback       Manual         1         Maruti
# 8358    Diesel        SUV       Manual         2        Renault
#
#                       Model  Model Year  Price     Insurance Validity  \
# 0            Maruti Celerio        2015   4.00  Third Party insurance
# 1             Ford Ecosport        2018   8.11          Comprehensive
# 2                Tata Tiago        2018   5.85          Comprehensive
# 3             Hyundai Xcent        2014   4.62          Comprehensive
# 4        Maruti SX4 S Cross        2015   7.90  Third Party insurance
# ...                     ...         ...    ...                    ...
# 8354         Maruti Celerio        2022   5.10  Third Party insurance
# 8355        Maruti Alto 800        2014   1.80  Third Party insurance
# 8356  Mercedes-Benz C-Class        2011   5.50  Third Party insurance
# 8357            Maruti Ritz        2012   1.40  Third Party insurance
# 8358         Renault Duster        2017   5.00  Third Party insurance
#
#       Kms Driven  Mileage  Seats   Color       City
# 0         120000    23.10      5   White  Bangalore
# 1          32706    17.00      5   White  Bangalore
# 2          11949    23.84      5     Red  Bangalore
# 3          17794    19.10      5  Others  Bangalore
# 4          60000    23.65      5    Gray  Bangalore
# ...          ...      ...    ...     ...        ...
# 8354       10000    25.24      5  Others    Kolkata
# 8355      120000    22.74      5  Others    Kolkata
# 8356       50000    11.74      5  Others    Kolkata
# 8357       40000    18.50      5  Others    Kolkata
# 8358      120000    19.72      5  Others    Kolkata
#
# [7440 rows x 14 columns]

# %%
df_filtered.reset_index(inplace=True,drop=True)
df_filtered
# Out:
#      Fuel Type  Body Type Transmission  Owner No          Brand  \
# 0       Petrol  Hatchback       Manual         3         Maruti
# 1       Petrol        SUV       Manual         2           Ford
# 2       Petrol  Hatchback       Manual         1           Tata
# 3       Petrol      Sedan       Manual         1        Hyundai
# 4       Diesel        SUV       Manual         1         Maruti
# ...        ...        ...          ...       ...            ...
# 7435    Petrol  Hatchback       Manual         1         Maruti
# 7436    Petrol  Hatchback       Manual         1         Maruti
# 7437    Petrol      Sedan    Automatic         3  Mercedes-Benz
# 7438    Petrol  Hatchback       Manual         1         Maruti
# 7439    Diesel        SUV       Manual         2        Renault
#
#                       Model  Model Year  Price     Insurance Validity  \
# 0            Maruti Celerio        2015   4.00  Third Party insurance
# 1             Ford Ecosport        2018   8.11          Comprehensive
# 2                Tata Tiago        2018   5.85          Comprehensive
# 3             Hyundai Xcent        2014   4.62          Comprehensive
# 4        Maruti SX4 S Cross        2015   7.90  Third Party insurance
# ...                     ...         ...    ...                    ...
# 7435         Maruti Celerio        2022   5.10  Third Party insurance
# 7436        Maruti Alto 800        2014   1.80  Third Party insurance
# 7437  Mercedes-Benz C-Class        2011   5.50  Third Party insurance
# 7438            Maruti Ritz        2012   1.40  Third Party insurance
# 7439         Renault Duster        2017   5.00  Third Party insurance
#
#       Kms Driven  Mileage  Seats   Color       City
# 0         120000    23.10      5   White  Bangalore
# 1          32706    17.00      5   White  Bangalore
# 2          11949    23.84      5     Red  Bangalore
# 3          17794    19.10      5  Others  Bangalore
# 4          60000    23.65      5    Gray  Bangalore
# ...          ...      ...    ...     ...        ...
# 7435       10000    25.24      5  Others    Kolkata
# 7436      120000    22.74      5  Others    Kolkata
# 7437       50000    11.74      5  Others    Kolkata
# 7438       40000    18.50      5  Others    Kolkata
# 7439      120000    19.72      5  Others    Kolkata
#
# [7440 rows x 14 columns]

# %%
# Check for duplicate rows
duplicates = df_filtered.duplicated()

# Show duplicate rows
duplicate_rows = df_filtered[df_filtered.duplicated()]

# %%
duplicate_rows
# Out:
#      Fuel Type  Body Type Transmission  Owner No       Brand  \
# 63      Petrol  Hatchback       Manual         2      Maruti
# 92      Petrol        SUV    Automatic         1     Hyundai
# 97      Petrol  Hatchback       Manual         3     Hyundai
# 146     Petrol  Hatchback       Manual         3      Maruti
# 160     Petrol      Sedan       Manual         1        Fiat
# ...        ...        ...          ...       ...         ...
# 7293    Petrol      Sedan    Automatic         1  Volkswagen
# 7342    Petrol        SUV    Automatic         1     Hyundai
# 7371    Petrol        MUV       Manual         1         Kia
# 7410    Petrol  Hatchback       Manual         1      Maruti
# 7421    Petrol      Sedan       Manual         1      Maruti
#
#                    Model  Model Year  Price     Insurance Validity  \
# 63           Maruti Ritz        2014   4.20  Third Party insurance
# 92         Hyundai Venue        2019  12.50  Third Party insurance
# 97           Hyundai i10        2009   2.49  Third Party insurance
# 146       Maruti Celerio        2015   4.00  Third Party insurance
# 160           Fiat Linea        2009   3.75  Third Party insurance
# ...                  ...         ...    ...                    ...
# 7293    Volkswagen Vento        2017   6.50          Comprehensive
# 7342       Hyundai Venue        2021   9.50          Comprehensive
# 7371          Kia Carens        2022  10.99          Comprehensive
# 7410        Maruti Swift        2021   6.50  Third Party insurance
# 7421  Maruti Swift Dzire        2019   5.50  Third Party insurance
#
#       Kms Driven    Mileage  Seats   Color       City
# 63         60000  18.500000      5  Silver  Bangalore
# 92         20000  18.150000      5  Others  Bangalore
# 97         80000  20.360000      5  Others  Bangalore
# 146       120000  23.100000      5   White  Bangalore
# 160        50000  16.000000      5    Gray  Bangalore
# ...          ...        ...    ...     ...        ...
# 7293       54000  18.190000      5    Grey    Kolkata
# 7342       29000  18.150000      5   White    Kolkata
# 7371       20000  19.245568      7   White    Kolkata
# 7410       10000  21.210000      5  Others    Kolkata
# 7421       40000  21.210000      5  Others    Kolkata
#
# [99 rows x 14 columns]

# %%
# Drop duplicate rows
df_filtered.drop_duplicates(inplace=True)
df_filtered
# Out:
# C:\Users\M Karan kumar\AppData\Local\Temp\ipykernel_5220\761574214.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered.drop_duplicates(inplace=True)
#      Fuel Type  Body Type Transmission  Owner No          Brand  \
# 0       Petrol  Hatchback       Manual         3         Maruti
# 1       Petrol        SUV       Manual         2           Ford
# 2       Petrol  Hatchback       Manual         1           Tata
# 3       Petrol      Sedan       Manual         1        Hyundai
# 4       Diesel        SUV       Manual         1         Maruti
# ...        ...        ...          ...       ...            ...
# 7435    Petrol  Hatchback       Manual         1         Maruti
# 7436    Petrol  Hatchback       Manual         1         Maruti
# 7437    Petrol      Sedan    Automatic         3  Mercedes-Benz
# 7438    Petrol  Hatchback       Manual         1         Maruti
# 7439    Diesel        SUV       Manual         2        Renault
#
#                       Model  Model Year  Price     Insurance Validity  \
# 0            Maruti Celerio        2015   4.00  Third Party insurance
# 1             Ford Ecosport        2018   8.11          Comprehensive
# 2                Tata Tiago        2018   5.85          Comprehensive
# 3             Hyundai Xcent        2014   4.62          Comprehensive
# 4        Maruti SX4 S Cross        2015   7.90  Third Party insurance
# ...                     ...         ...    ...                    ...
# 7435         Maruti Celerio        2022   5.10  Third Party insurance
# 7436        Maruti Alto 800        2014   1.80  Third Party insurance
# 7437  Mercedes-Benz C-Class        2011   5.50  Third Party insurance
# 7438            Maruti Ritz        2012   1.40  Third Party insurance
# 7439         Renault Duster        2017   5.00  Third Party insurance
#
#       Kms Driven  Mileage  Seats   Color       City
# 0         120000    23.10      5   White  Bangalore
# 1          32706    17.00      5   White  Bangalore
# 2          11949    23.84      5     Red  Bangalore
# 3          17794    19.10      5  Others  Bangalore
# 4          60000    23.65      5    Gray  Bangalore
# ...          ...      ...    ...     ...        ...
# 7435       10000    25.24      5  Others    Kolkata
# 7436      120000    22.74      5  Others    Kolkata
# 7437       50000    11.74      5  Others    Kolkata
# 7438       40000    18.50      5  Others    Kolkata
# 7439      120000    19.72      5  Others    Kolkata
#
# [7341 rows x 14 columns]

# %%
# Show duplicate rows
duplicate_rows = df_filtered[df_filtered.duplicated()]

# %%
duplicate_rows.count()
# Out:
# Fuel Type             0
# Body Type             0
# Transmission          0
# Owner No              0
# Brand                 0
# Model                 0
# Model Year            0
# Price                 0
# Insurance Validity    0
# Kms Driven            0
# Mileage               0
# Seats                 0
# Color                 0
# City                  0
# dtype: int64

# %%
max_price_index = df_filtered["Price"].idxmax()
max_price_row = df_filtered.loc[max_price_index]
print(max_price_row)
# Out:
# Fuel Type                     Diesel
# Body Type                        SUV
# Transmission               Automatic
# Owner No                           1
# Brand                        Hyundai
# Model                 Hyundai Tucson
# Model Year                      2017
# Price                          18.25
# Insurance Validity     Comprehensive
# Kms Driven                     57000
# Mileage                        16.38
# Seats                              5
# Color                          White
# City                       Bangalore
# Name: 112, dtype: object

# %%
final_data=df_filtered
final_data
# Out:
#      Fuel Type  Body Type Transmission  Owner No          Brand  \
# 0       Petrol  Hatchback       Manual         3         Maruti
# 1       Petrol        SUV       Manual         2           Ford
# 2       Petrol  Hatchback       Manual         1           Tata
# 3       Petrol      Sedan       Manual         1        Hyundai
# 4       Diesel        SUV       Manual         1         Maruti
# ...        ...        ...          ...       ...            ...
# 7435    Petrol  Hatchback       Manual         1         Maruti
# 7436    Petrol  Hatchback       Manual         1         Maruti
# 7437    Petrol      Sedan    Automatic         3  Mercedes-Benz
# 7438    Petrol  Hatchback       Manual         1         Maruti
# 7439    Diesel        SUV       Manual         2        Renault
#
#                       Model  Model Year  Price     Insurance Validity  \
# 0            Maruti Celerio        2015   4.00  Third Party insurance
# 1             Ford Ecosport        2018   8.11          Comprehensive
# 2                Tata Tiago        2018   5.85          Comprehensive
# 3             Hyundai Xcent        2014   4.62          Comprehensive
# 4        Maruti SX4 S Cross        2015   7.90  Third Party insurance
# ...                     ...         ...    ...                    ...
# 7435         Maruti Celerio        2022   5.10  Third Party insurance
# 7436        Maruti Alto 800        2014   1.80  Third Party insurance
# 7437  Mercedes-Benz C-Class        2011   5.50  Third Party insurance
# 7438            Maruti Ritz        2012   1.40  Third Party insurance
# 7439         Renault Duster        2017   5.00  Third Party insurance
#
#       Kms Driven  Mileage  Seats   Color       City
# 0         120000    23.10      5   White  Bangalore
# 1          32706    17.00      5   White  Bangalore
# 2          11949    23.84      5     Red  Bangalore
# 3          17794    19.10      5  Others  Bangalore
# 4          60000    23.65      5    Gray  Bangalore
# ...          ...      ...    ...     ...        ...
# 7435       10000    25.24      5  Others    Kolkata
# 7436      120000    22.74      5  Others    Kolkata
# 7437       50000    11.74      5  Others    Kolkata
# 7438       40000    18.50      5  Others    Kolkata
# 7439      120000    19.72      5  Others    Kolkata
#
# [7341 rows x 14 columns]

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7341 entries, 0 to 7439
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Fuel Type           7341 non-null   object
#  1   Body Type           7341 non-null   object
#  2   Transmission        7341 non-null   object
#  3   Owner No            7341 non-null   int64
#  4   Brand               7341 non-null   object
#  5   Model               7341 non-null   object
#  6   Model Year          7341 non-null   int64
#  7   Price               7341 non-null   float64
#  8   Insurance Validity  7341 non-null   object
#  9   Kms Driven          7341 non-null   int64
#  10  Mileage             7341 non-null   float64
#  11  Seats               7341 non-null   int64
#  12  Color               7341 non-null   object
#  13  City                7341 non-null   object
# dtypes: float64(2), int64(4), object(8)
# memory usage: 1.1+ MB

# %%
path=r"C:\Users\M Karan kumar\1JupyterNoteBOOk\CARDHEKO\final_data.csv"
final_data.to_csv(path,index=False)
